# %%
#********************************************************************************************************
# Método para recuperação matriz de valores distintos. Por exemplo, no DataFrame 'countries',a coluna 
# 'continent' tem entradas repetidas. Há um método que recupera uma matriz de valores distintos de uma
# coluna específica do DataFrame.
#********************************************************************************************************

import pandas as pd

country_data = {'country' : ['Thailand', 'Philippines', 'Monaco', 'Malta', 'Sweden', 'Paraguay', 'Latvia'],
          'continent' : ['Asia', 'Asia', 'Europe', 'Europe', 'Europe', 'South America', 'Europe'],
          'capital':['Bangkok', 'Manila', 'Monaco', 'Valletta', 'Stockholm', 'Asuncion', 'Riga']}

countries = pd.DataFrame(country_data)

unique_countries = countries['country'].unique()
unique_continents = countries['continent'].unique()
unique_capitais = countries['capital'].unique()
print("=" * 115)

print(f"Continentes: {unique_continents} ->  Total = {countries['continent'].nunique()} continentes")
print("=" * 115)
print(f"Países:      {unique_countries}  ->  Total = {countries['country'].nunique()} países") 
print("=" * 115)
print(f"Capitais:    {unique_capitais}   ->  Total = {countries['capital'].nunique()} capitais")
print("=" * 115)
# Out:
# ...
# Continentes: ['Asia' 'Europe' 'South America'] ->  Total = 3 continentes
# ...
# Países:      ['Thailand' 'Philippines' 'Monaco' 'Malta' 'Sweden' 'Paraguay' 'Latvia']  ->  Total = 7 países
# ...
# Capitais:    ['Bangkok' 'Manila' 'Monaco' 'Valletta' 'Stockholm' 'Asuncion' 'Riga']   ->  Total = 7 capitais
# ...
