# %%
import pandas as pd
paises_data = {'Países' : ['Tailândia', 'Filipinas', 'Mônaco', 'Malta', 'Suécia', 'Paraguai', 'Letônia'],
               'continentes' : ['Asia', 'Asia', 'Europa', 'Europa', 'Europa', 'America do Sul', 'Europa'],
               'capitais':['Bangkok', 'Manila', 'Monaco', 'Valletta', 'Estolcomo', 'Assunção', 'Riga']}

countries = pd.DataFrame(paises_data)

countries.insert(3, 'População', [61399000, 75967000, 39244, 380200, 10380491, 5496000, 2424200])
countries.insert(4,'Religião',['Budismo', 'Católica', 'Católica', 'Católica', 'Protestante', 'Católica', 'Ortodoxa'])
print(countries)
# Out:
#       Países     continentes   capitais  População     Religião
# 0  Tailândia            Asia    Bangkok   61399000      Budismo
# 1  Filipinas            Asia     Manila   75967000     Católica
# 2     Mônaco          Europa     Monaco      39244     Católica
# 3      Malta          Europa   Valletta     380200     Católica
# 4     Suécia          Europa  Estolcomo   10380491  Protestante
# 5   Paraguai  America do Sul   Assunção    5496000     Católica
# 6    Letônia          Europa       Riga    2424200     Ortodoxa
