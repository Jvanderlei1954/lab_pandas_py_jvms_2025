# %%
####
# Visualização de Dados
###
import pandas as pd
import numpy as np

# Reprodutibilidade (para outras libs que usem NumPy)
np.random.seed(5)

wine_data = pd.read_csv(
    'https://codefinity-content-media.s3.eu-west-1.amazonaws.com/a43d24b6-df61-4e11-9c90-5b36552b3437/wine.csv'
)

# Resultados
first_lines  = wine_data.head(10)
last_lines   = wine_data.tail(15)
random_rows  = wine_data.sample(n=12, random_state=5)  # <-- garante reprodutibilidade

# Exibir
print(first_lines)
print(last_lines)
print(random_rows)
# Out:
#    Unnamed: 0  fixed acidity  volatile acidity  citric acid  residual sugar
# 0           0            7.4              0.70         0.00             1.9
# 1           1            7.8              0.88         0.00             2.6
# 2           2            7.8              0.76         0.04             2.3
# 3           3           11.2              0.28         0.56             1.9
# 4           4            7.4              0.70         0.00             1.9
# 5           5            7.4              0.66         0.00             1.8
# 6           6            7.9              0.60         0.06             1.6
# 7           7            7.3              0.65         0.00             1.2
# 8           8            7.8              0.58         0.02             2.0
# 9           9            6.7              0.58         0.08             1.8
#      Unnamed: 0  fixed acidity  volatile acidity  citric acid  residual sugar
# ...
