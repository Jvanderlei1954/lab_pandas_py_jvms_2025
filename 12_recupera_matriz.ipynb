# %%
#=========================================
# Recuperando matriz com valores distintos
#=========================================
import pandas as pd 

cars_data = {'model': ['audi A1', 'audi A6', 'audi A4', 'audi A3','audi A1'],
             'year': [2017, 2016, 2017, 2019, 2016],
             'fueltype': ['petrol', 'diesel', 'diesel', 'petrol', 'petrol'],
             'capital': ['Manila', 'Monaco', 'Bangkok', 'Stockhol', 'Valletta']}

audi_cars = pd.DataFrame(cars_data)

# Find unique values
unique_years = audi_cars['year'].unique()
unique_fueltype = audi_cars['fueltype'].unique()
count_unique_fueltypes = audi_cars['fueltype'].nunique()

print(f" Veículos de anos distintos: {unique_years}")
print(f" Tipos de combustíveis utilizados: {unique_fueltype}")
print(f" Qtde de combustíveis utilizados: {count_unique_fueltypes}")
# Out:
#  Veículos de anos distintos: [2017 2016 2019]
#  Tipos de combustíveis utilizados: ['petrol' 'diesel']
#  Qtde de combustíveis utilizados: 2
