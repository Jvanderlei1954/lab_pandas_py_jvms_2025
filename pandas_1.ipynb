# %%
import pandas as pd
people_data = {'name' : ['Ann', 'Alex', 'Kevin', 'Kate'], 
          'age' : [35, 12, 24, 45]}

people_df = pd.DataFrame(people_data)
print(people_df)
# Out:
#     name  age
# 0    Ann   35
# 1   Alex   12
# 2  Kevin   24
# 3   Kate   45
